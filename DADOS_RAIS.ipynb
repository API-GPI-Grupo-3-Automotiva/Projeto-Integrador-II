# %% [markdown]
# <a href="https://colab.research.google.com/github/API-GPI-Grupo-3-Automotiva/Projeto-Integrador-II/blob/main/DADOS_RAIS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DADOS DA RAIS

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
origem = '/content/drive/MyDrive/Data/RAIS/'

# %%
file_1 = origem + 'RAIS_ESTAB_PUB.txt'
rais24 = pd.read_csv(file_1,low_memory=False,sep =';',encoding = 'latin1')

# %%
file_2 = origem + 'diretorio_uf_brasil.csv'
UF = pd.read_csv(file_2,low_memory=False,sep =';',encoding ='latin1')

# %%
rais24.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12643067 entries, 0 to 12643066
# Data columns (total 24 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Bairros SP                 int64
#  1   Bairros Fortaleza          int64
#  2   Bairros RJ                 int64
#  3   CNAE 2.0 Classe            int64
#  4   CNAE 95 Classe             int64
#  5   Distritos SP               int64
#  6   Qtd Vínculos CLT           int64
#  7   Qtd Vínculos Ativos        int64
#  8   Qtd Vínculos Estatutários  int64
#  9   Ind Atividade Ano          int64
#  10  Ind CEI Vinculado          int64
#  11  Ind Estab Participa PAT    int64
#  12  Ind Rais Negativa          int64
#  13  Ind Simples                int64
#  14  Município                  int64
#  15  Natureza Jurídica          int64
#  16  Regiões Adm DF             int64
#  17  CNAE 2.0 Subclasse         int64
#  18  Tamanho Estabelecimento    int64
# ...

# %%
UF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Codigo_UF    27 non-null     int64
#  1   UF           27 non-null     object
#  2   Nome_Estado  27 non-null     object
#  3   Região       27 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 996.0+ bytes

# %%
UF.head()
# Out:
#    Codigo_UF  UF Nome_Estado Região
# 0         11  RO    Rondônia  Norte
# 1         12  AC        Acre  Norte
# 2         13  AM    Amazonas  Norte
# 3         14  RR     Roraima  Norte
# 4         15  PA        Pará  Norte

# %%
UF[UF['UF']=='SP']
# Out:
#     Codigo_UF  UF Nome_Estado   Região
# 19         35  SP   São Paulo  Sudeste

# %%
rais24['UF'].unique()
# Out:
# array(['11', '12', '13', '14', '15', '16', '17', '21', '22', '23', '24',
#        '25', '26', '27', '28', '29', '31', '32', '33', '35', '41', '42',
#        '43', '50', '51', '52', '53', '{ñ'], dtype=object)

# %%
rais_final = rais24[rais24['UF'] == '35']
rais_final = rais_final.reset_index(drop=True)

# %%
rais_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3157330 entries, 0 to 3157329
# Data columns (total 24 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   Bairros SP                 int64
#  1   Bairros Fortaleza          int64
#  2   Bairros RJ                 int64
#  3   CNAE 2.0 Classe            int64
#  4   CNAE 95 Classe             int64
#  5   Distritos SP               int64
#  6   Qtd Vínculos CLT           int64
#  7   Qtd Vínculos Ativos        int64
#  8   Qtd Vínculos Estatutários  int64
#  9   Ind Atividade Ano          int64
#  10  Ind CEI Vinculado          int64
#  11  Ind Estab Participa PAT    int64
#  12  Ind Rais Negativa          int64
#  13  Ind Simples                int64
#  14  Município                  int64
#  15  Natureza Jurídica          int64
#  16  Regiões Adm DF             int64
#  17  CNAE 2.0 Subclasse         int64
#  18  Tamanho Estabelecimento    int64
#  19  Tipo Estab                 int64
# ...

# %%
rais_final.to_csv(origem + 'rais_final.csv', index=False)
